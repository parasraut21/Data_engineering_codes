# %%
head , tail , summary , describe , shape

# %% [markdown]
# In the field of Data Science, CSV files are used to store large datasets. To efficiently analyze such datasets, we need to convert them into pandas DataFrame.

# %%
import numpy as np # linear algebra Used for numerical operations and working with arrays.
import pandas as pd # Great for data manipulation and analysis, especially with tabular data (like CSV files).
import matplotlib.pyplot as plt # This is for creating static, animated, and interactive visualizations in Python.

# %%
from google.colab import files # The line from google.colab import files is used to handle file uploads and downloads in Colab.

# %%
# Upload a CSV file
uploaded = files.upload()

# Read data from the uploaded file
file_path = list(uploaded.keys())[0]
df = pd.read_csv(file_path)
# Out:
#      <input type="file" id="files-91b4c223-06d1-49a9-844f-aa77a6269bde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91b4c223-06d1-49a9-844f-aa77a6269bde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
# Display basic statistics about the data
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
df['Gender'].value_counts()
# Out:
# Female    204
# Male      196
# Name: Gender, dtype: int64

# %%
# check for null values
df.isnull().sum() # would give you a series showing the count of missing values in each column of your DataFrame.
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
 # is likely used to find the maximum value for each column in the DataFrame iris_ds.
 # When applied to a Pandas DataFrame, this function returns the maximum value along each column.

 df.max()
# Out:
# User ID            15815236
# Gender                 Male
# Age                      60
# EstimatedSalary      150000
# Purchased                 1
# dtype: object

# %%
df.mean() # is likely used to calculate the mean (average) value for each column in the DataFrame
# Out:
# <ipython-input-17-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# User ID            1.569154e+07
# Age                3.765500e+01
# EstimatedSalary    6.974250e+04
# Purchased          3.575000e-01
# dtype: float64

# %%
#The sample median is the “middle” data point, after ordering the dataset.
df.median() # The median is the middle value of a dataset, separating it into two equal halves. Unlike the mean, the median is not affected by extreme values (outliers),
                 # making it a robust measure of central tendency.
# Out:
# <ipython-input-18-4c0729170e00>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median() # The median is the middle value of a dataset, separating it into two equal halves. Unlike the mean, the median is not affected by extreme values (outliers),
# User ID            15694341.5
# Age                      37.0
# EstimatedSalary       70000.0
# Purchased                 0.0
# dtype: float64

# %%
#get the dimensionality of dataframe
df.shape
# Out:
# (400, 5)

# %%
#checking for missing values
df.isnull()
# Out:
#      User ID  Gender    Age  EstimatedSalary  Purchased
# 0      False   False  False            False      False
# 1      False   False  False            False      False
# 2      False   False  False            False      False
# 3      False   False  False            False      False
# 4      False   False  False            False      False
# ..       ...     ...    ...              ...        ...
# 395    False   False  False            False      False
# 396    False   False  False            False      False
# 397    False   False  False            False      False
# 398    False   False  False            False      False
# 399    False   False  False            False      False
#
# [400 rows x 5 columns]

# %%
# Reading Specific Columns
#The loc property is used to access a group of rows and columns by label(s) or a boolean array.
print (df.loc[:,['Age','Gender']])
# Out:
#      Age  Gender
# 0     19    Male
# 1     35    Male
# 2     26  Female
# 3     27  Female
# 4     19    Male
# ..   ...     ...
# 395   46  Female
# 396   51    Male
# 397   50  Female
# 398   36    Male
# 399   49  Female
#
# [400 rows x 2 columns]

# %%
#Reading Specific Columns and Rows
print (df.loc[[1,3,5],['Age','Gender']])
# Out:
#    Age  Gender
# 1   35    Male
# 3   27  Female
# 5   27    Male

# %%
# filling missing value using fillna()
df['Gender'].fillna('No',inplace=True)
df.head(15)
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 0   15624510    Male   19            19000          0
# 1   15810944    Male   35            20000          0
# 2   15668575  Female   26            43000          0
# 3   15603246  Female   27            57000          0
# 4   15804002    Male   19            76000          0
# 5   15728773    Male   27            58000          0
# 6   15598044  Female   27            84000          0
# 7   15694829  Female   32           150000          1
# 8   15600575    Male   25            33000          0
# 9   15727311  Female   35            65000          0
# 10  15570769  Female   26            80000          0
# 11  15606274  Female   26            52000          0
# 12  15746139    Male   20            86000          0
# 13  15704987    Male   32            18000          0
# 14  15628972    Male   18            82000          0

# %%
# filling missing value using median()
print ( "fill the missing values.")
median = df["Age"].median()
print(median)
df["Age"].fillna(median, inplace=True)
print(df.describe())
print("\n")
print(df)
# Out:
# fill the missing values.
# 37.0
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000
#
#
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ...

# %%
# filling missing value using std()
print ( "fill the missing values.")
std = df["Salary"].std()
print(std)
dataset["Salary"].fillna(std, inplace=True)
print(dataset.describe())
print("\n")
print(dataset)

# %%
# drop rows with missing values
df.dropna(inplace=True)
df.shape
# Out:
# (400, 5)

# %%
# dropping duplicate values
dataset = df.drop_duplicates()
print(dataset)
df.shape
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]
# (400, 5)

# %%
df.shape
# Out:
# (400, 5)
